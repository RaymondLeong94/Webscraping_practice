# %% [markdown]
# Notebook for webscraping practice

# %%
#load in the file from scraping.
import json
import pandas as pd
books = pd.read_json('booksdata.json')

# %%
books
# Out:
#                                                    url  \
# 0    https://books.toscrape.com/catalogue/rip-it-up...
# 1    https://books.toscrape.com/catalogue/the-dirty...
# 2    https://books.toscrape.com/catalogue/the-requi...
# 3    https://books.toscrape.com/catalogue/set-me-fr...
# 4    https://books.toscrape.com/catalogue/shakespea...
# ..                                                 ...
# 995  https://books.toscrape.com/catalogue/fighting-...
# 996  https://books.toscrape.com/catalogue/1st-to-di...
# 997  https://books.toscrape.com/catalogue/forever-r...
# 998  https://books.toscrape.com/catalogue/frankenst...
# 999  https://books.toscrape.com/catalogue/1000-plac...
#
#                                                  title upc product_type  \
# 0                            Rip it Up and Start Again   a        books
# 1    The Dirty Little Secrets of Getting Your Dream...   2        books
# 2                                      The Requiem Red   f        books
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             1000 non-null   object
#  1   title           1000 non-null   object
#  2   upc             1000 non-null   object
#  3   product_type    1000 non-null   object
#  4   price_excl_tax  1000 non-null   float64
#  5   price_incl_tax  1000 non-null   float64
#  6   tax             1000 non-null   int64
#  7   availability    1000 non-null   int64
#  8   num_reviews     1000 non-null   int64
#  9   stars           1000 non-null   int64
#  10  category        1000 non-null   object
#  11  description     1000 non-null   object
#  12  price           1000 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 101.7+ KB

# %% [markdown]
# Let's build some machine learning algorithims and pipelines

# %%
y_variable = books.price
data = books.drop(columns= ['price'])
#write out some machine learning algo 
machine_algo_1 = ['DT', 'RF'] #decision tree, logistic regression, linear regression
metrics_to_measure = ['accuracy', 'roc_auc']


continuous_variables = data.select_dtypes(include=['int', 'float'])
categorical_variables =data.select_dtypes(include  = ['object'])
